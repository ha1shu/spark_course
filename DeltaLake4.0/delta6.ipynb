# %% [markdown]
# ### **Table Utility Commands**

# %%
# %sql
describe delta .`/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`

# %%
# %sql
describe extended delta .`/Volumes/deltalakefirstcatalog/default/deltalogvolume1/SchemaLevel/`

# %%
# %sql
describe history delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`

# %%
# %sql
select * from delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`

# %%
df = spark.read.format("delta") \
    .load("/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/")

df = df.dropDuplicates(["id"])

df.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/")

# %%
# %sql
Select * from delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`

# %%
# %sql
describe history delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`

# %%
# %sql
Restore delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`
To version as of 6

# %%
# %sql
Select * from delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`

# %%
# %sql
describe history delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`

# %%
# %sql
Restore delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`
To version as of 7

# %%
# %sql
Show tblproperties delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`

# %%
# %sql
create table deltalakefirstcatalog.default.first_clone 
Clone delta . `/Volumes/deltalakefirstcatalog/default/deltalogvolume1/dmlSink1/`

# %%
# %sql
select * from deltalakefirstcatalog.default.first_clone
