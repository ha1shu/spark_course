# %% [markdown]
# ### **Delta log schema level chaneges**

# %%
data = [(1,'Harshit',1100),(2,'Rohit',2200),(3,'Shivani',3300)]

df = spark.createDataFrame(data,["id","name","salary"])
df.write.format("delta").mode("append").save("/Volumes/deltalakefirstcatalog/default/deltalogvolume1/SchemaLevel/")
df.display()

# %%
# %sql
ALTER TABLE delta.`/Volumes/deltalakefirstcatalog/default/deltalogvolume1/SchemaLevel/` 
SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name');

ALTER TABLE delta.`/Volumes/deltalakefirstcatalog/default/deltalogvolume1/SchemaLevel/`
RENAME COLUMN name TO Customer_name

# %%
df = spark.read.format("delta").load("/Volumes/deltalakefirstcatalog/default/deltalogvolume1/SchemaLevel/")
df.display()

# %%
df_log_read = spark.read.format('json').load('/Volumes/deltalakefirstcatalog/default/deltalogvolume1/SchemaLevel/_delta_log/00000000000000000002.json')
df_log_read.display()
